# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# random latitudes and longitudes comboms
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

combo_lats_lngs = zip(lats, lngs)

combo_lats_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
test_coord = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in test_coord:
    print(coordinate[0], coordinate[1])

# loops in x and y values in a tuple()
# [(25.12903645,-67.59741259),(25.92017388,11.09532135), (), (), ]
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list (1500 items)
coordinates = list(combo_lats_lngs)

coordinates
# Out:
# [(-78.20131517672388, -172.01800683672877),
#  (65.21983098970074, 174.46703284377185),
#  (-21.695921237039812, -78.4390550945582),
#  (-26.729938796349245, -23.73243967411551),
#  (37.66154106008584, -55.62275988581551),
#  (68.66269260444054, -113.952249902325),
#  (-72.0382380533639, -44.09198174654122),
#  (-72.68971237145615, 114.31480739049101),
#  (14.548547385878209, 21.444108763775745),
#  (57.07126170621595, -78.4374321044325),
#  (73.15729902279273, 112.78541965625527),
#  (-63.56206813521281, 12.009666849616025),
#  (5.014206389545507, 25.582820094735723),
#  (59.814074073697554, -136.78067593090998),
#  (27.290593402953675, -133.64310926391906),
#  (7.48809861086211, -46.50110679262639),
#  (-0.379546710785192, 31.421105401673486),
#  (-33.897994775657914, -93.03405079838072),
#  (-17.45650052195947, 1.31111983816254),
#  (-14.252036978261415, 108.84178590644132),
#  (15.816739960194738, -165.16656242986687),
#  (1.4941620634816104, 66.94737049695621),
# ...

# %%
# !pip install citipy

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy as ctp

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(ctp.nearest_city(coordinate[0], coordinate[1]).city_name,
          ctp.nearest_city(coordinate[0], coordinate[1]).country_code)

# iterate thro test_coord
# use citipy.nearest_city()
# for loop will iterate the values in test_coord thro the index "coordinate[]"
# then will provide city name
# then will provide country initials
# Out:
# vaini to
# anadyr ru
# marcona pe
# vila velha br
# saint-pierre pm
# yellowknife ca
# ushuaia ar
# albany au
# biltine td
# attawapiskat ca
# saskylakh ru
# hermanus za
# zemio cf
# haines junction ca
# pacific grove us
# cayenne gf
# kyotera ug
# lebu cl
# jamestown sh
# bambanglipuro id
# kapaa us
# thinadhoo mv
# punta arenas cl
# rikitea pf
# necochea ar
# saleaula ws
# katsuura jp
# altay cn
# klaksvik fo
# tres arroyos ar
# kuruman za
# adamantina br
# halifax ca
# barentsburg sj
# barahona do
# guerrero negro mx
# ponta do sol cv
# tanggu cn
# kapaa us
# berdigestyakh ru
# illoqqortoormiut gl
# cidreira br
# ushuaia ar
# geraldton au
# altamira br
# dikson ru
# upernavik gl
# puerto ayora ec
# upernavik gl
# mar del plata ar
# narsaq gl
# mahibadhoo mv
# belomorsk ru
# syracuse it
# jacareacanga br
# amderma ru
# bengkulu id
# east london za
# cape town za
# ushuaia ar
# port alfred za
# pingdu cn
# dikson ru
# punta arenas cl
# souillac mu
# yulara au
# kloulklubed pw
# ...

# %%
# creating a true list of cities without duplicates

# a dictionary to store the names about to appended
cities = []

# Identifying nearest city for each lat and long combo

for coordinate in coordinates:
    city = ctp.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if city is unique, then it is added, no so duplicates
    if city not in cities:
        cities.append(city)
        
# print the lenght of the cities
len(cities)
# Out:
# 604

# %%
list(cities)
# Out:
# ['vaini',
#  'anadyr',
#  'marcona',
#  'vila velha',
#  'saint-pierre',
#  'yellowknife',
#  'ushuaia',
#  'albany',
#  'biltine',
#  'attawapiskat',
#  'saskylakh',
#  'hermanus',
#  'zemio',
#  'haines junction',
#  'pacific grove',
#  'cayenne',
#  'kyotera',
#  'lebu',
#  'jamestown',
#  'bambanglipuro',
#  'kapaa',
#  'thinadhoo',
#  'punta arenas',
#  'rikitea',
#  'necochea',
#  'saleaula',
#  'katsuura',
#  'altay',
#  'klaksvik',
#  'tres arroyos',
#  'kuruman',
#  'adamantina',
#  'halifax',
#  'barentsburg',
#  'barahona',
#  'guerrero negro',
#  'ponta do sol',
#  'tanggu',
#  'berdigestyakh',
#  'illoqqortoormiut',
#  'cidreira',
#  'geraldton',
#  'altamira',
#  'dikson',
#  'upernavik',
#  'puerto ayora',
#  'mar del plata',
#  'narsaq',
#  'mahibadhoo',
#  'belomorsk',
#  'syracuse',
#  'jacareacanga',
#  'amderma',
#  'bengkulu',
#  'east london',
#  'cape town',
#  'port alfred',
#  'pingdu',
#  'souillac',
#  'yulara',
#  'kloulklubed',
#  'meghri',
# ...

# %%
# importing requests for API call
import requests

# importing api key saved in config file
from config import weather_api_key

# %%
# # Starting URL for Weather Map API Call

# # testing a city name

# test_city = "Sacramento"
# url_test = f"http://api.openweathermap.org/data/2.5/weather?q={test_city}&appid={weather_api_key}"

# print(url_test)

# %%
# another method 

# Starting URL for Weather Map API Call.
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"
print(url)

#  added imperial units 

# Create an endpoint URL for a city.
city_url = f"{url}&q=Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=23d3cb6c78a98daea99a5de04bb3fd7d
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=23d3cb6c78a98daea99a5de04bb3fd7d&q=Boston

# %%
boston_get_api = requests.get(city_url)

boston_get_api

# response 200 means ok!
# Out:
# <Response [200]>

# %%
# get request for city weather

boston_get_api = requests.get(city_url)

# boston_test_api.text too complicated

# boston_get_api.json()['sys']['country']

boston_list = boston_get_api.json()

# creating key value pairs for boston

lat = boston_list["coord"]["lat"]
lng = boston_list["coord"]["lon"]
max_temp = boston_list["main"]["temp_max"]
humidity = boston_list["main"]["humidity"]
clouds = boston_list["clouds"]["all"]
wind = boston_list["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.36 -71.06 72 52 2 10.29

# %%
from datetime import datetime

# converting boston ["dt"] into actualy ISO standarized yyyy:mm:dd:hh:mm:ss

correct_date = boston_list["dt"]

datetime.utcfromtimestamp(correct_date)

# converting that into a readable date using strftime()

datetime.utcfromtimestamp(correct_date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2020-06-27 05:36:41'

# %%
from datetime import datetime

# %%
# # declaring empty list

# city_data = []

# # printing begining of logging

# print("Beginning Data Retreival           ")
# print("------------------------------------")

# # creating counters

# record_count = 1

# set_count = 1

# # setting records here so when we loop arounf 50 sets of cities at a time, we can find and keep track
# # of the number of loops, as the records themselves will be looped through
# Out:
# Beginning Data Retreival
# ------------------------------------

# %%
# looping thro cities to build a url, 50 cities at a time
# # enumerate in for loops access indexes and key:pair values at the same time

# for i, city in enumerate(cities):
     
# #         group cities in sets of 50 for control and logging purposes

# #         checking if remainder of i/50 is 0

#     if (i % 50 == 0 and i >=50):
        
# #         if true then sets count and record = 1

#         set_count += 1
    
#         record_count = 1
    
# #     creating endpoint URL with each city
# #     city_url = f"{url}&aq{city.replace(" ","+")}"
#     city_url = f"{url}&aq{city.replace(' ','+')}"
    
# #     log url, record, and set numbers and the city
#     print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
# #     incrementing record count
#     record_count += 1
# Out:
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | anadyr
# Processing Record 3 of Set 1 | marcona
# Processing Record 4 of Set 1 | vila velha
# Processing Record 5 of Set 1 | saint-pierre
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | biltine
# Processing Record 10 of Set 1 | attawapiskat
# Processing Record 11 of Set 1 | saskylakh
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | zemio
# Processing Record 14 of Set 1 | haines junction
# Processing Record 15 of Set 1 | pacific grove
# Processing Record 16 of Set 1 | cayenne
# Processing Record 17 of Set 1 | kyotera
# Processing Record 18 of Set 1 | lebu
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | bambanglipuro
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | thinadhoo
# Processing Record 23 of Set 1 | punta arenas
# ...

# %%
# # Run an API request for each of the cities.
#     try:
#         # Parse the JSON and retrieve data.
#         city_weather = requests.get(city_url).json()
#         # Parse out the needed data.
#         city_lat = city_weather["coord"]["lat"]
#         city_lng = city_weather["coord"]["lon"]
#         city_max_temp = city_weather["main"]["temp_max"]
#         city_humidity = city_weather["main"]["humidity"]
#         city_clouds = city_weather["clouds"]["all"]
#         city_wind = city_weather["wind"]["speed"]
#         city_country = city_weather["sys"]["country"]
#         # Convert the date to ISO standard.
#         city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
#         # Append the city information into city_data list.
#         city_data.append({"City": city.title(),
#                           "Lat": city_lat,
#                           "Lng": city_lng,
#                           "Max Temp": city_max_temp,
#                           "Humidity": city_humidity,
#                           "Cloudiness": city_clouds,
#                           "Wind Speed": city_wind,
#                           "Country": city_country,
#                           "Date": city_date})

# # If an error is experienced, skip the city.
#     except:
#         print("City not found. Skipping...")
#         pass

# # Indicate that Data Loading is complete.
# print("-----------------------------")
# print("Data Retrieval Complete      ")
# print("-----------------------------")
# Out:
# 2

# %% [markdown]
# # Get City Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# importing requests for API call
import requests

# importing api key saved in config file
from config import weather_api_key

# %%
# random latitudes and longitudes comboms
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

combo_lats_lngs = zip(lats, lngs)

combo_lats_lngs

# %%
# Add the latitudes and longitudes to a list (1500 items)
coordinates = list(combo_lats_lngs)

coordinates
# Out:
# [(38.829706004572245, -82.99586459249383),
#  (48.07526391845664, 96.17595858666027),
#  (11.785592272976245, -39.19356834467436),
#  (42.429813308654985, -59.97909988342178),
#  (-1.570309008067909, -165.89808452135762),
#  (33.45849235900026, -132.37309159087755),
#  (-78.11217145000766, -5.706262678540526),
#  (-5.549137490347732, 112.65006021116506),
#  (-28.87158665914903, -117.09004651690614),
#  (-77.18399487696982, 177.75370718026937),
#  (-55.730597864229196, 100.62529377160604),
#  (89.93575353216411, -123.2318766737701),
#  (-88.98350061466459, -23.50363237292916),
#  (43.191462650924876, -167.8241632820418),
#  (-74.04787289117593, 41.53173468198199),
#  (-38.02637518284769, -166.8435215566413),
#  (-57.85430628453655, 72.98915396368352),
#  (-1.396997610295827, 51.581138213348794),
#  (-81.08605036696028, 9.989351964767792),
#  (-6.2558771874548995, -52.14967565772396),
#  (23.171457596930964, -6.558374919296455),
#  (45.224198395141656, 26.398928742720017),
# ...

# %%
# creating a true list of cities without duplicates

# a dictionary to store the names about to appended
cities = []

# Identifying nearest city for each lat and long combo

for coordinate in coordinates:
    city = ctp.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if city is unique, then it is added, no so duplicates
    if city not in cities:
        cities.append(city)
        
# print the lenght of the cities
len(cities)
# Out:
# 626

# %%
list(cities)
# Out:
# ['portsmouth',
#  'erzin',
#  'carutapera',
#  'port hawkesbury',
#  'samalaeulu',
#  'half moon bay',
#  'hermanus',
#  'paciran',
#  'rikitea',
#  'kaitangata',
#  'busselton',
#  'tuktoyaktuk',
#  'ushuaia',
#  'bethel',
#  'port alfred',
#  'avarua',
#  'saint-philippe',
#  'victoria',
#  'sao felix do xingu',
#  'taoudenni',
#  'cislau',
#  'salalah',
#  'atuona',
#  'biltine',
#  'tocopilla',
#  'thompson',
#  'itapirapua',
#  'pevek',
#  'bluff',
#  'bombay',
#  'tautira',
#  'taolanaro',
#  'hilo',
#  'pierre',
#  'shieli',
#  'chokurdakh',
#  'kyren',
#  'sinkat',
#  'east london',
#  'upernavik',
#  'zaoyang',
#  'mataura',
#  'vostok',
#  'viedma',
#  'fortuna',
#  'doctor pedro p. pena',
#  'yumen',
#  'vaitupu',
#  'ahuimanu',
#  'la sarre',
#  'bilma',
#  'husavik',
#  'makakilo city',
#  'saskylakh',
#  'kloulklubed',
#  'ngunguru',
#  'honningsvag',
#  'dikson',
#  'puerto ayora',
#  'georgetown',
#  'port elizabeth',
#  'hithadhoo',
#  'hambantota',
#  'korla',
# ...

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# declaring empty list to collect data from api

city_data = []

# printing begining of logging

print("Beginning Data Retreival           ")
print("------------------------------------")

# creating counters

record_count = 1

set_count = 1

# setting records here so when we loop arounf 50 sets of cities at a time, we can find and keep track
# of the number of loops, as the records themselves will be looped through

for i, city in enumerate(cities):
    print(i, city)
    
#     grouping cities by sets of 50 to log and check
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
#   creating endpoint url for each city
#   since the city names have space in between them, this replaces the space with a plus for the url
    city_url = f"{url}&q={city.replace(' ','+')}"
    
#   log url record and set numbers to check processing
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
#   add 1 to every record added 
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data, assign a variable first
        city_weather = requests.get(city_url).json()
        # Parse out the needed data, separate
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list, precursor to a dataframe
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
#       countinues the loop without stopping
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
    
    
    
    
    
len(city_data)
# Out:
# Beginning Data Retreival
# ------------------------------------
# 0 portsmouth
# Processing Record 1 of Set 1 | portsmouth
# 1 erzin
# Processing Record 2 of Set 1 | erzin
# 2 carutapera
# Processing Record 3 of Set 1 | carutapera
# 3 port hawkesbury
# Processing Record 4 of Set 1 | port hawkesbury
# 4 samalaeulu
# Processing Record 5 of Set 1 | samalaeulu
# City not found. Skipping...
# 5 half moon bay
# Processing Record 6 of Set 1 | half moon bay
# 6 hermanus
# Processing Record 7 of Set 1 | hermanus
# 7 paciran
# Processing Record 8 of Set 1 | paciran
# 8 rikitea
# Processing Record 9 of Set 1 | rikitea
# 9 kaitangata
# Processing Record 10 of Set 1 | kaitangata
# 10 busselton
# Processing Record 11 of Set 1 | busselton
# 11 tuktoyaktuk
# Processing Record 12 of Set 1 | tuktoyaktuk
# 12 ushuaia
# Processing Record 13 of Set 1 | ushuaia
# 13 bethel
# Processing Record 14 of Set 1 | bethel
# 14 port alfred
# Processing Record 15 of Set 1 | port alfred
# 15 avarua
# ...

# %%
# converting to a dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# reordering columns
new_cols = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_cols]

city_data_df

# saving the dataframe as a csv file in the folder

convert_df2csv = "weather_data/cities.csv"

city_data_df.to_csv(convert_df2csv, index_label = "City_ID")

city_data_df = pd.read_csv("weather_data/cities.csv")

city_data_df.head(10)
# Out:
#    City_ID             City Country                 Date    Lat     Lng  \
# 0        0       Portsmouth      GB  2020-06-27 19:08:42  50.80   -1.09
# 1        1            Erzin      TR  2020-06-27 19:10:28  36.96   36.20
# 2        2       Carutapera      BR  2020-06-27 19:10:29  -1.20  -46.02
# 3        3  Port Hawkesbury      CA  2020-06-27 19:05:39  45.62  -61.35
# 4        4    Half Moon Bay      US  2020-06-27 19:07:50  37.46 -122.43
# 5        5         Hermanus      ZA  2020-06-27 19:07:21 -34.42   19.23
# 6        6          Paciran      ID  2020-06-27 19:10:30  -6.88  112.38
# 7        7          Rikitea      PF  2020-06-27 19:10:30 -23.12 -134.97
# 8        8       Kaitangata      NZ  2020-06-27 19:07:25 -46.28  169.85
# 9        9        Busselton      AU  2020-06-27 19:07:19 -33.65  115.33
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     61.00        82          88        7.00
# 1     77.00        89           0        0.87
# ...

# %%
# adding scatter plots of latitude vs various weather indicies

lats_data = city_data_df['Lat']
maxtemp_data = city_data_df['Max Temp']
humidity_data = city_data_df["Humidity"]
cloudiness_data = city_data_df["Cloudiness"]
wind_speed_data = city_data_df["Wind Speed"]

wind_speed_data.head(10)
# Out:
# 0     7.00
# 1     0.87
# 2     6.58
# 3    12.75
# 4     6.93
# 5     3.00
# 6     6.04
# 7    14.99
# 8     4.00
# 9    23.87
# Name: Wind Speed, dtype: float64

# %%
# importing time module
import time 

# scatter plot build lats vs max temp

plt.scatter(lats_data, 
            maxtemp_data,
            edgecolor='black',
            linewidths=1,
            marker="o",
            label="Cities")

plt.title(f"City Latitude vs Max Temperature {time.strftime('%x')}")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# saving plot
plt.savefig("weather_data/Fig1.png")

# show plot
plt.show()

# %%
# humiditiy

plt.scatter(lats_data, 
            humidity_data,
            edgecolor='black',
            linewidths=1,
            marker="o",
            label="Cities",
            alpha=0.8)

plt.title(f"City Latitude vs Humidity {time.strftime('%x')}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig2.png")

# Show plot.
plt.show()

# %%
# cloudiness

plt.scatter(lats_data, 
            cloudiness_data,
            edgecolor='black',
            linewidths=1,
            marker="o",
            label="Cities")

plt.title(f"City Latitude vs Cloudiness (%) {time.strftime('%x')}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig3.png")

# Show plot.
plt.show()

# %%
# wind speed

plt.scatter(lats_data, 
            wind_speed_data,
            edgecolor='black',
            linewidths=1,
            marker="o",
            label="Cities")

plt.title(f"City Latitude vs Wind Speed {time.strftime('%x')}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig4.png")

# Show plot.
plt.show()

# %%
# creating a linear regression function with defining variables with an algorithm

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.

def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
#   running regression on the weather data
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
#   calculating regression line y values from slope and intercept like y=mx+b
    regress_values = ((slope * x_values) + intercept)
    
#   equation of the line with f string
    line_eq = f"(y={str(round(slope, 2))}x+{str(round(intercept,2))})"
    
#   creating a scatter plot
    plt.scatter(x_values, y_values)
    
    plt.plot(x_values, regress_values, "r")
    
#   annotating the regress line equation in the plotted chart
    plt.annotate(line_eq, text_coordinates, color="red")
    
#   plotting the rest
    plt.title(title)
    plt.xlabel("Latitude")
    plt.ylabel(y_label)

    plt.show()

# %%
# assingning northern and souther hemisphere df using .loc to filter values above or below 0 in 'Lat'
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>=0]
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0]

southern_hemi_df.head(5)
# Out:
#    City_ID        City Country                 Date    Lat     Lng  Max Temp  \
# 2        2  Carutapera      BR  2020-06-27 19:10:29  -1.20  -46.02     80.44
# 5        5    Hermanus      ZA  2020-06-27 19:07:21 -34.42   19.23     55.99
# 6        6     Paciran      ID  2020-06-27 19:10:30  -6.88  112.38     76.50
# 7        7     Rikitea      PF  2020-06-27 19:10:30 -23.12 -134.97     71.91
# 8        8  Kaitangata      NZ  2020-06-27 19:07:25 -46.28  169.85     50.00
#
#    Humidity  Cloudiness  Wind Speed
# 2        89          23        6.58
# 5        82          76        3.00
# 6        83          63        6.04
# 7        70          10       14.99
# 8        92         100        4.00

# %%
# calling all the values that need to be replaced in the plot linear regression function

# plot_linear_regression(x_values, y_values, title, y_label, text_coordinates)

# northern hemisphere linear regression max temps

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]


plot_linear_regression(x_values,
                       y_values,
                       "Linear Regression on the Northern Hemisphere \nfor Maximum Temperature",
                       "Max Temp",(5,30))

# %%
# Linear regression on the Southern Hemisphere max temps
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor Maximum Temperature',
                       'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere humidity
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for % Humidity',
                       '% Humidity',(55,10))

# %%
# Linear regression on the Southern Hemisphere humidity
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor % Humidity',
                       '% Humidity',(-50,15))

# %%
# Linear regression on the Southern Hemisphere cloudiness
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor % Cloudiness',
                       '% Cloudiness',(10,57))

# %%
# Linear regression on the Southern Hemisphere cloudiness
x_values = southern_hemi_df["Lat"] 
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor % Cloudiness',
                       '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor Wind Speed',
                       'Wind Speed (mph)',(3,25))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor Wind Speed',
                       'Wind Speed (mph)',(-50,30))

# %%
# !pip install gmaps
# Out:
# ...
#   Created wheel for gmaps: filename=gmaps-0.9.0-py2.py3-none-any.whl size=2076101 sha256=a966b7c0059c590609525c11fb4111433cc5825b40f88c26566e0a8c0b8f279b
#   Stored in directory: c:\users\ssing\appdata\local\pip\cache\wheels\3d\1c\cb\c46f4199210e632b28d78d05a00bfdccbf6dfcd3f5b051d6bf
# Successfully built gmaps
# ...
